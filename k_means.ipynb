# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv(r"C:\Users\eswar\OneDrive\Desktop\ML_example\Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
# x = df['YearsExperience']
# y = df['']

# %%
model = KMeans(n_clusters=2,random_state=42)
model.fit(df)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
model.transform(df)
# Out:
# array([[15227.23544055, 64687.46191306],
#        [ 8365.23551257, 57825.46193378],
#        [16839.23538112, 66299.46186315],
#        [11045.23536059, 60505.46184209],
#        [14679.23532899, 64139.4618063 ],
#        [ 2071.76472934, 47388.46181956],
#        [ 5579.7647099 , 43880.46183038],
#        [  125.23529467, 49585.46177678],
#        [ 9874.76470589, 39585.46183699],
#        [ 2618.76475139, 46841.46174152],
#        [ 8647.76473327, 40812.46175063],
#        [ 1223.76495974, 48236.46170945],
#        [ 2386.76483604, 47073.46171368],
#        [ 2510.764863  , 46949.4617056 ],
#        [ 6540.76483274, 42919.46168623],
#        [13367.76481249, 36092.46167693],
#        [11458.76486146, 38001.46165386],
#        [28517.76478234, 20942.46172053],
#        [26792.76484074, 22667.46164152],
#        [39369.76480462, 10090.46174905],
#        [37167.76487909, 12292.4616032 ],
#        [43702.76487885,  5757.46161875],
#        [46731.76494105,  2728.46154324],
# ...

# %%
model.predict(df) # 
res=model.predict(df)

# %%
df['res']=res
df.groupby('res').get_group(1)
# Out:
#     YearsExperience    Salary  res
# 17              5.4   83089.0    1
# 18              6.0   81364.0    1
# 19              6.1   93941.0    1
# 20              6.9   91739.0    1
# 21              7.2   98274.0    1
# 22              8.0  101303.0    1
# 23              8.3  113813.0    1
# 24              8.8  109432.0    1
# 25              9.1  105583.0    1
# 26              9.6  116970.0    1
# 27              9.7  112636.0    1
# 28             10.4  122392.0    1
# 29             10.6  121873.0    1

# %%
model.cluster_centers_
# Out:
# array([[3.31176471e+00, 5.45712353e+04],
#        [8.16153846e+00, 1.04031462e+05]])

# %%
# PCA
from sklearn.decomposition import PCA
import seaborn as sns

# %%
sns.scatterplot(data=df,x='YearsExperience',y='Salary',hue='res')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
pca_ = PCA(n_components=2)
pca_.fit_transform(df)
# Out:
# array([[-3.66600002e+04, -5.20012807e-01],
#        [-2.97980003e+04, -9.95799890e-01],
#        [-3.82720002e+04,  3.49527187e-02],
#        [-3.24780002e+04, -3.84614263e-02],
#        [-3.61120001e+04,  5.16831342e-01],
#        [-1.93610001e+04, -4.34644276e-01],
#        [-1.58530002e+04, -6.80101951e-01],
#        [-2.15580001e+04,  7.86365468e-02],
#        [-1.15580002e+04, -9.03718495e-01],
#        [-1.88140001e+04,  3.04840689e-01],
#        [-1.27850001e+04, -8.91162188e-02],
#        [-2.02090000e+04,  7.39336637e-01],
#        [-1.90460000e+04,  6.25088746e-01],
#        [-1.89220000e+04,  7.12060017e-01],
#        [-1.48920000e+04,  7.12780828e-01],
#        [-8.06500001e+03,  4.38736934e-01],
#        [-9.97399998e+03,  8.24573458e-01],
#        [ 7.08499997e+03, -7.82839097e-01],
#        [ 5.36000004e+03, -1.84680127e-02],
#        [ 1.79370000e+04, -1.15482348e+00],
#        [ 1.57350001e+04, -1.45289110e-01],
#        [ 2.22700001e+04, -4.89800710e-01],
# ...

# %%
pca_.explained_variance_
# Out:
# array([7.51550968e+08, 3.51941488e-01])

# %%
import matplotlib.pyplot as plt
